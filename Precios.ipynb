# %% [markdown]
# # Cargar datos
# <hr>

# %%
import pandas as pd

# %%
df_duales = pd.read_csv("df_mejores/Inhibidores/duales.csv")
df_Bases = pd.read_csv("df_mejores/Bases/bases.csv")

# %%
df_duales
# Out:
#             Molecula Target  \
# 0     MAPK1_P_EGFR_0   EGFR
# 1    MAPK1_P_EGFR_14   EGFR
# 2    MAPK1_P_EGFR_18   EGFR
# 3    MAPK1_P_EGFR_20   EGFR
# 4    MAPK1_P_EGFR_24   EGFR
# ..               ...    ...
# 100   EGFR_P_SRC_229    SRC
# 101   EGFR_P_SRC_230    SRC
# 102   EGFR_P_SRC_231    SRC
# 103   EGFR_P_SRC_233    SRC
# 104   EGFR_P_SRC_234    SRC
#
#                                                   Ruta   Afinidad     CNN  \
# 0    Mejores_poses/inhibidores/MAPK1_P_EGFR_0_EGFR....  -9.873798  active
# 1    Mejores_poses/inhibidores/MAPK1_P_EGFR_14_EGFR...  -9.668670  active
# 2    Mejores_poses/inhibidores/MAPK1_P_EGFR_18_EGFR...  -9.393104  active
# 3    Mejores_poses/inhibidores/MAPK1_P_EGFR_20_EGFR...  -9.341337  active
# 4    Mejores_poses/inhibidores/MAPK1_P_EGFR_24_EGFR...  -9.505371  active
# ..                                                 ...        ...     ...
# 100  Mejores_poses/inhibidores/EGFR_P_SRC_229_SRC.p... -10.237829  active
# 101  Mejores_poses/inhibidores/EGFR_P_SRC_230_SRC.p... -10.327303  active
# 102  Mejores_poses/inhibidores/EGFR_P_SRC_231_SRC.p... -10.078071  active
# 103  Mejores_poses/inhibidores/EGFR_P_SRC_233_SRC.p...  -9.388470  active
# 104  Mejores_poses/inhibidores/EGFR_P_SRC_234_SRC.p...  -9.295660  active
#
#     CNN afinity
# 0          ('A'
# 1          ('A'
# 2          ('A'
# 3          ('A'
# 4          ('A'
# ..          ...
# 100        ('A'
# 101        ('A'
# 102        ('A'
# 103        ('A'
# 104        ('A'
#
# [105 rows x 6 columns]

# %%
df_Bases
# Out:
#           Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 0   EGFR_MAPK1_101  -10.027432  -10.522901          ('A'          ('A'
# 1   EGFR_MAPK1_114   -9.835052  -10.348002          ('A'          ('A'
# 2   EGFR_MAPK1_117  -10.195214  -10.207559          ('A'          ('A'
# 3   EGFR_MAPK1_134  -10.132882  -10.266725          ('A'          ('A'
# 4   EGFR_MAPK1_136   -9.852680  -10.731030          ('A'          ('A'
# ..             ...         ...         ...           ...           ...
# 61    EGFR_SRC_564  -11.626127   -9.953917          ('A'          ('A'
# 62    EGFR_SRC_565  -11.939290  -10.491311          ('A'          ('A'
# 63    EGFR_SRC_566  -11.901248  -10.111121          ('A'          ('A'
# 64    EGFR_SRC_567  -11.347662  -10.426674          ('A'          ('A'
# 65    EGFR_SRC_569  -10.000343   -9.550843          ('A'          ('A'
#
#      CNN_1   CNN_2                                             Ruta_1  \
# 0   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_101_E...
# 1   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_114_E...
# 2   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_117_E...
# 3   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_134_E...
# 4   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_136_E...
# ..     ...     ...                                                ...
# 61  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_564_EGF...
# 62  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_565_EGF...
# 63  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_566_EGF...
# 64  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_567_EGF...
# 65  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_569_EGF...
#
#                                                Ruta_2 Target_1 Target_2  \
# 0   Mejores_poses/bases_conjuntas/EGFR_MAPK1_101_M...     EGFR    MAPK1
# 1   Mejores_poses/bases_conjuntas/EGFR_MAPK1_114_M...     EGFR    MAPK1
# 2   Mejores_poses/bases_conjuntas/EGFR_MAPK1_117_M...     EGFR    MAPK1
# 3   Mejores_poses/bases_conjuntas/EGFR_MAPK1_134_M...     EGFR    MAPK1
# 4   Mejores_poses/bases_conjuntas/EGFR_MAPK1_136_M...     EGFR    MAPK1
# ..                                                ...      ...      ...
# 61  Mejores_poses/bases_conjuntas/EGFR_SRC_564_SRC...     EGFR      SRC
# 62  Mejores_poses/bases_conjuntas/EGFR_SRC_565_SRC...     EGFR      SRC
# 63  Mejores_poses/bases_conjuntas/EGFR_SRC_566_SRC...     EGFR      SRC
# 64  Mejores_poses/bases_conjuntas/EGFR_SRC_567_SRC...     EGFR      SRC
# 65  Mejores_poses/bases_conjuntas/EGFR_SRC_569_SRC...     EGFR      SRC
#
#        Targets
# 0   EGFR_MAPK1
# 1   EGFR_MAPK1
# 2   EGFR_MAPK1
# 3   EGFR_MAPK1
# 4   EGFR_MAPK1
# ..         ...
# 61    EGFR_SRC
# 62    EGFR_SRC
# 63    EGFR_SRC
# 64    EGFR_SRC
# 65    EGFR_SRC
#
# [66 rows x 12 columns]

# %% [markdown]
# # Cargar referencias
# <hr>

# %%
IDS_bases = pd.read_csv("IDS/df_bases.csv")
IDS_inhibidores = pd.read_csv("IDS/df_inhibidores.csv")

# %%
IDS_bases
# Out:
#                                                 SMILES  \
# 0    C/C(=C/CC[C@@H](C)[C@@H]1CC[C@]2(C)C3=CCC4C(C)...
# 1    C/C(=C\CC[C@H](C)[C@@H]1CC[C@]2(C)C3=CCC4C(C)(...
# 2    C[C@H](CC[C@@H](O)C(C)(C)O)[C@@H]1CC[C@@]2(C(=...
# 3    CC(C)=CCC[C@@H](C)[C@H]1CC[C@@]2(C)C3=CC[C@@]4...
# 4    CC(C)=CCC[C@H](C)[C@@H]1CC[C@]2(C)C3=CC[C@H]4C...
# ..                                                 ...
# 588  O=C(NCC1=CC=CN=C1)[C@H]1CN2CC[C@H]1C[C@@H]2CN1...
# 589                    CCC(C(=O)OCCOCCN(CC)CC)c1ccccc1
# 590        COc1cc2c(NCCCCCO[N+](=O)[O-])ncnc2c(OC)c1OC
# 591                     CCCOc1cc(N)ccc1C(=O)OCCN(CC)CC
# 592  CCN1C(=O)C(C)(C)C2=CC3=C(C=C21)C1=C(N3)C2=C(CC...
#
#                                                 Nombre      EGFR     MAPK1  \
# 0                                                  NaN  0.922429  0.915159
# 1    (E,6S)-2-methyl-6-[(10R,13S,14S,17S)-4,4,10,13...  0.922429  0.915159
# 2                                                  NaN  0.928582  0.926768
# 3                                                  NaN  0.945426  0.944940
# 4                                                  NaN  0.939520  0.919611
# ..                                                 ...       ...       ...
# 588                                                NaN  0.912304  0.071742
# 589                                 butamirate citrate  0.923914  0.461465
# 590                                               KT 1  0.977872  0.075074
# 591                         PROPOXYCAINE HYDROCHLORIDE  0.932808  0.148395
# 592  5-ethyl-7,7,16-trimethyl-5,11,14,15-tetrazapen...  0.424132  0.909347
#
#           SRC     STAT3      mean       BBB     Targets  peso_molecular  \
# 0    0.230000  0.135191  0.550695  0.185000  EGFR MAPK1         454.695
# 1    0.230000  0.135191  0.550695  0.185000  EGFR MAPK1         454.695
# 2    0.170000  0.053530  0.519720  0.100000  EGFR MAPK1         488.709
# 3    0.260000  0.033167  0.545883  0.265000  EGFR MAPK1         438.740
# 4    0.210000  0.069483  0.534654  0.170000  EGFR MAPK1         424.713
# ..        ...       ...       ...       ...         ...             ...
# 588  0.275000  0.901213  0.540065  0.010000  EGFR STAT3         422.577
# 589  0.165000  0.930930  0.620327  0.780000  EGFR STAT3         307.434
# 590  0.885000  0.940082  0.719507  0.160000  EGFR STAT3         366.374
# 591  0.667581  0.904663  0.663362  1.000000  EGFR STAT3         294.395
# 592  1.000000  0.639726  0.743301  0.511667   MAPK1 SRC         348.450
#
#         logP  donadores_H  aceptores_H  violaciones Targets_nuevo  \
# 0    7.60790          1.0          2.0          1.0    EGFR_MAPK1
# 1    7.60790          1.0          2.0          1.0    EGFR_MAPK1
# 2    5.60740          3.0          4.0          1.0    EGFR_MAPK1
# 3    8.93330          0.0          1.0          1.0    EGFR_MAPK1
# 4    8.54320          0.0          1.0          1.0    EGFR_MAPK1
# ..       ...          ...          ...          ...           ...
# 588  2.82270          1.0          6.0          0.0    EGFR_STAT3
# 589  3.08180          0.0          4.0          0.0    EGFR_STAT3
# 590  2.44610          1.0          9.0          0.0    EGFR_STAT3
# 591  2.55620          1.0          5.0          0.0    EGFR_STAT3
# 592  3.99922          2.0          2.0          0.0     MAPK1_SRC
#
#                                    ruta              ID
# 0    Bases_conjuntas/Targets/EGFR_MAPK1    EGFR_MAPK1_0
# 1    Bases_conjuntas/Targets/EGFR_MAPK1    EGFR_MAPK1_1
# 2    Bases_conjuntas/Targets/EGFR_MAPK1    EGFR_MAPK1_2
# 3    Bases_conjuntas/Targets/EGFR_MAPK1    EGFR_MAPK1_3
# 4    Bases_conjuntas/Targets/EGFR_MAPK1    EGFR_MAPK1_4
# ..                                  ...             ...
# 588  Bases_conjuntas/Targets/EGFR_STAT3  EGFR_STAT3_588
# 589  Bases_conjuntas/Targets/EGFR_STAT3  EGFR_STAT3_589
# 590  Bases_conjuntas/Targets/EGFR_STAT3  EGFR_STAT3_590
# 591  Bases_conjuntas/Targets/EGFR_STAT3  EGFR_STAT3_591
# 592   Bases_conjuntas/Targets/MAPK1_SRC   MAPK1_SRC_592
#
# [593 rows x 17 columns]

# %%
df_Bases.rename(columns={"Molecula": "ID"}, inplace=True)
df_duales.rename(columns={"Molecula": "ID"}, inplace=True)

# %%
merge_bases = pd.merge(df_Bases, IDS_bases, on="ID", how="left")
merge_duales = pd.merge(df_duales, IDS_inhibidores, on="ID", how="left")

# %%
merge_duales
# Out:
#                   ID Target  \
# 0     MAPK1_P_EGFR_0   EGFR
# 1    MAPK1_P_EGFR_14   EGFR
# 2    MAPK1_P_EGFR_18   EGFR
# 3    MAPK1_P_EGFR_20   EGFR
# 4    MAPK1_P_EGFR_24   EGFR
# ..               ...    ...
# 100   EGFR_P_SRC_229    SRC
# 101   EGFR_P_SRC_230    SRC
# 102   EGFR_P_SRC_231    SRC
# 103   EGFR_P_SRC_233    SRC
# 104   EGFR_P_SRC_234    SRC
#
#                                                   Ruta   Afinidad     CNN  \
# 0    Mejores_poses/inhibidores/MAPK1_P_EGFR_0_EGFR....  -9.873798  active
# 1    Mejores_poses/inhibidores/MAPK1_P_EGFR_14_EGFR...  -9.668670  active
# 2    Mejores_poses/inhibidores/MAPK1_P_EGFR_18_EGFR...  -9.393104  active
# 3    Mejores_poses/inhibidores/MAPK1_P_EGFR_20_EGFR...  -9.341337  active
# 4    Mejores_poses/inhibidores/MAPK1_P_EGFR_24_EGFR...  -9.505371  active
# ..                                                 ...        ...     ...
# 100  Mejores_poses/inhibidores/EGFR_P_SRC_229_SRC.p... -10.237829  active
# 101  Mejores_poses/inhibidores/EGFR_P_SRC_230_SRC.p... -10.327303  active
# 102  Mejores_poses/inhibidores/EGFR_P_SRC_231_SRC.p... -10.078071  active
# 103  Mejores_poses/inhibidores/EGFR_P_SRC_233_SRC.p...  -9.388470  active
# 104  Mejores_poses/inhibidores/EGFR_P_SRC_234_SRC.p...  -9.295660  active
#
#     CNN afinity       Targets Molecule ChEMBL ID        EGFR      MAPK1  ...  \
# 0          ('A'  MAPK1 P EGFR      CHEMBL2408790    0.929761   0.285700  ...
# 1          ('A'  MAPK1 P EGFR      CHEMBL3663113    0.906100  89.240000  ...
# 2          ('A'  MAPK1 P EGFR      CHEMBL3654759    0.925110  13.550000  ...
# 3          ('A'  MAPK1 P EGFR      CHEMBL3654684    0.911419  15.150000  ...
# 4          ('A'  MAPK1 P EGFR      CHEMBL3662966    0.908146   3.661000  ...
# ..          ...           ...                ...         ...        ...  ...
# 100        ('A'    EGFR P SRC       CHEMBL335648   19.000000   0.834418  ...
# 101        ('A'    EGFR P SRC       CHEMBL113023  250.000000   0.120216  ...
# 102        ('A'    EGFR P SRC       CHEMBL325589  510.000000   0.077353  ...
# 103        ('A'    EGFR P SRC       CHEMBL168285  790.000000   0.210638  ...
# 104        ('A'    EGFR P SRC       CHEMBL169390   80.000000   0.232963  ...
#
#           BBB                                             SMILES  \
# 0    0.000000  COc1cccc(F)c1CN1CCC[C@@H](NC(=O)Nc2cc3[nH]nc(-...
# 1    0.170000  O=C(NCc1ccc(F)cc1)Nc1cc2[nH]nc(-c3ccc(OC(F)(F)...
# 2    0.010000  C[C@@H](NC(=O)Nc1cc2[nH]nc(C(=O)NCC3CCN(C4CC4)...
# 3    0.100000  COc1ccc(CNC(=O)Nc2cc3[nH]nc(-c4ccc(F)cc4)c3cn2...
# 4    0.795000  Cc1cc(-c2n[nH]c3cc(NC(=O)NCc4cnccc4C(F)(F)F)nc...
# ..        ...                                                ...
# 100  0.013333  CO[C@H]1[C@@H]([N+](C)(C)C)C[C@@H]2O[C@@]1(C)n...
# 101  0.195000  COc1ccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O)n(C)c3n...
# 102  0.020000    Cn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(Nc3cccnc3)nc21
# 103  0.695000                Nc1ncnc2c1c(-c1ccccc1)cn2C1CCC(O)C1
# 104  0.030000                Nc1ncnc2c1c(-c1cccc(O)c1)cn2C1CCCC1
#
#      peso_molecular     logP donadores_H  aceptores_H  violaciones  \
# 0           489.555  4.26212         3.0          6.0          0.0
# 1           445.376  4.98430         3.0          4.0          0.0
# 2           447.543  3.05470         4.0          5.0          0.0
# 3           421.432  4.10290         3.0          5.0          0.0
# 4           427.390  4.06382         3.0          5.0          0.0
# ..              ...      ...         ...          ...          ...
# 100         495.603  4.84080         1.0          5.0          0.0
# 101         441.318  5.36292         1.0          6.0          1.0
# 102         398.253  4.44090         1.0          6.0          0.0
# 103         294.358  2.76640         2.0          5.0          0.0
# 104         294.358  3.50120         2.0          5.0          0.0
#
#      Targets_nuevo  after_P_                      ruta
# 0     MAPK1_P_EGFR      EGFR  Inhibidores/Targets/EGFR
# 1     MAPK1_P_EGFR      EGFR  Inhibidores/Targets/EGFR
# 2     MAPK1_P_EGFR      EGFR  Inhibidores/Targets/EGFR
# 3     MAPK1_P_EGFR      EGFR  Inhibidores/Targets/EGFR
# 4     MAPK1_P_EGFR      EGFR  Inhibidores/Targets/EGFR
# ..             ...       ...                       ...
# 100     EGFR_P_SRC       SRC   Inhibidores/Targets/SRC
# 101     EGFR_P_SRC       SRC   Inhibidores/Targets/SRC
# 102     EGFR_P_SRC       SRC   Inhibidores/Targets/SRC
# 103     EGFR_P_SRC       SRC   Inhibidores/Targets/SRC
# 104     EGFR_P_SRC       SRC   Inhibidores/Targets/SRC
#
# [105 rows x 23 columns]

# %%
merge_bases
# Out:
#                 ID  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 0   EGFR_MAPK1_101  -10.027432  -10.522901          ('A'          ('A'
# 1   EGFR_MAPK1_114   -9.835052  -10.348002          ('A'          ('A'
# 2   EGFR_MAPK1_117  -10.195214  -10.207559          ('A'          ('A'
# 3   EGFR_MAPK1_134  -10.132882  -10.266725          ('A'          ('A'
# 4   EGFR_MAPK1_136   -9.852680  -10.731030          ('A'          ('A'
# ..             ...         ...         ...           ...           ...
# 61    EGFR_SRC_564  -11.626127   -9.953917          ('A'          ('A'
# 62    EGFR_SRC_565  -11.939290  -10.491311          ('A'          ('A'
# 63    EGFR_SRC_566  -11.901248  -10.111121          ('A'          ('A'
# 64    EGFR_SRC_567  -11.347662  -10.426674          ('A'          ('A'
# 65    EGFR_SRC_569  -10.000343   -9.550843          ('A'          ('A'
#
#      CNN_1   CNN_2                                             Ruta_1  \
# 0   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_101_E...
# 1   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_114_E...
# 2   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_117_E...
# 3   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_134_E...
# 4   active  active  Mejores_poses/bases_conjuntas/EGFR_MAPK1_136_E...
# ..     ...     ...                                                ...
# 61  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_564_EGF...
# 62  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_565_EGF...
# 63  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_566_EGF...
# 64  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_567_EGF...
# 65  active  active  Mejores_poses/bases_conjuntas/EGFR_SRC_569_EGF...
#
#                                                Ruta_2 Target_1  ...      mean  \
# 0   Mejores_poses/bases_conjuntas/EGFR_MAPK1_101_M...     EGFR  ...  0.657998
# 1   Mejores_poses/bases_conjuntas/EGFR_MAPK1_114_M...     EGFR  ...  0.554577
# 2   Mejores_poses/bases_conjuntas/EGFR_MAPK1_117_M...     EGFR  ...  0.548608
# 3   Mejores_poses/bases_conjuntas/EGFR_MAPK1_134_M...     EGFR  ...  0.535676
# 4   Mejores_poses/bases_conjuntas/EGFR_MAPK1_136_M...     EGFR  ...  0.543652
# ..                                                ...      ...  ...       ...
# 61  Mejores_poses/bases_conjuntas/EGFR_SRC_564_SRC...     EGFR  ...  0.712549
# 62  Mejores_poses/bases_conjuntas/EGFR_SRC_565_SRC...     EGFR  ...  0.698095
# 63  Mejores_poses/bases_conjuntas/EGFR_SRC_566_SRC...     EGFR  ...  0.712549
# 64  Mejores_poses/bases_conjuntas/EGFR_SRC_567_SRC...     EGFR  ...  0.753886
# 65  Mejores_poses/bases_conjuntas/EGFR_SRC_569_SRC...     EGFR  ...  0.783943
#
#          BBB   Targets_y peso_molecular    logP  donadores_H  aceptores_H  \
# 0   0.245000  EGFR MAPK1        472.589  4.2957          1.0          5.0
# 1   0.455000  EGFR MAPK1        460.699  4.8589          4.0          4.0
# 2   0.380000  EGFR MAPK1        480.686  2.4903          6.0          6.0
# 3   0.385000  EGFR MAPK1        446.672  4.7553          3.0          4.0
# 4   0.570000  EGFR MAPK1        468.634  4.9624          1.0          5.0
# ..       ...         ...            ...     ...          ...          ...
# 61  0.000000    EGFR SRC        482.540  3.8449          3.0          7.0
# 62  0.030000    EGFR SRC        480.524  3.9942          2.0          7.0
# 63  0.278333    EGFR SRC        482.540  3.8449          3.0          7.0
# 64  0.000000    EGFR SRC        482.540  4.4197          3.0          7.0
# 65  0.300000    EGFR SRC        440.507  4.2173          1.0          7.0
#
#     violaciones  Targets_nuevo                                ruta
# 0           0.0     EGFR_MAPK1  Bases_conjuntas/Targets/EGFR_MAPK1
# 1           0.0     EGFR_MAPK1  Bases_conjuntas/Targets/EGFR_MAPK1
# 2           1.0     EGFR_MAPK1  Bases_conjuntas/Targets/EGFR_MAPK1
# 3           0.0     EGFR_MAPK1  Bases_conjuntas/Targets/EGFR_MAPK1
# 4           0.0     EGFR_MAPK1  Bases_conjuntas/Targets/EGFR_MAPK1
# ..          ...            ...                                 ...
# 61          0.0       EGFR_SRC    Bases_conjuntas/Targets/EGFR_SRC
# 62          0.0       EGFR_SRC    Bases_conjuntas/Targets/EGFR_SRC
# 63          0.0       EGFR_SRC    Bases_conjuntas/Targets/EGFR_SRC
# 64          0.0       EGFR_SRC    Bases_conjuntas/Targets/EGFR_SRC
# 65          0.0       EGFR_SRC    Bases_conjuntas/Targets/EGFR_SRC
#
# [66 rows x 28 columns]

# %% [markdown]
# # Guardar datos
# <hr>

# %%
merge_bases.to_excel("Precios/merge_bases.xlsx", index=False)
merge_duales.to_excel("Precios/merge_duales.xlsx", index=False)
