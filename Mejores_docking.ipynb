# %% [markdown]
# # Índice
# <hr>

# %% [markdown]
# 1. [Cargar datos](#Cargar-datos)
#    Cargar archivos .pdbqt, .csv y otros datos necesarios.
#
# 2. [Analizar bases conjuntas](#analizar-bases-conjuntas)
#    Unir, filtrar y transformar los datos de las bases iniciales.
#
# 3. [Analizar inhibidores](#analizar-inhibidores)
#    Comparar resultados y extraer información clave de los ligandos.

# %% [markdown]
# # Cargar datos
# <hr>

# %%
# Definir puntajes de corte
my_dick = {"EGFR": -9.29, "MAPK1": -10.15, "SRC": -7.8, "STAT3": -9.41}

# %%
import pandas as pd

df_bases = pd.read_csv("Resultados_docking/Bases_conjuntas/Duales.csv", index_col=0)
df_inhib_dual = pd.read_csv("Resultados_docking/Inhibidores/Duales.csv", index_col=0)
df_inhib_triples = pd.read_csv("Resultados_docking/Inhibidores/Triples.csv", index_col=0)

# %%
df_bases
# Out:
#            Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 0      EGFR_MAPK1_0   -9.926985   -9.637679          ('A'          ('A'
# 1      EGFR_MAPK1_1  -10.250636   -9.380951          ('A'          ('A'
# 2     EGFR_MAPK1_10   -9.456389   -9.226347          ('A'          ('A'
# 3    EGFR_MAPK1_100   -9.750537   -9.207376          ('A'          ('A'
# 4    EGFR_MAPK1_101  -10.027432  -10.522901          ('A'          ('A'
# ..              ...         ...         ...           ...           ...
# 585  EGFR_STAT3_588   -8.902377   -7.607981          ('A'          ('A'
# 586  EGFR_STAT3_589   -6.214093   -5.034519          ('A'          ('A'
# 587  EGFR_STAT3_590   -6.864700   -6.152542          ('A'          ('A'
# 588  EGFR_STAT3_591   -6.480401   -5.409953          ('A'          ('A'
# 589   MAPK1_SRC_592   -9.875381  -10.006908          ('A'          ('A'
#
#       CNN_1   CNN_2                                             Ruta_1  \
# ...

# %%
df_inhib_dual
# Out:
#              Molecula Target  \
# 0    EGFR_P_MAPK1_158  MAPK1
# 1    EGFR_P_MAPK1_159  MAPK1
# 2    EGFR_P_MAPK1_160  MAPK1
# 3    EGFR_P_MAPK1_161  MAPK1
# 4    EGFR_P_MAPK1_162  MAPK1
# ..                ...    ...
# 316   SRC_P_STAT3_312  STAT3
# 317   SRC_P_STAT3_313  STAT3
# 318   SRC_P_STAT3_314  STAT3
# 319   SRC_P_STAT3_315  STAT3
# 320   SRC_P_STAT3_316  STAT3
#
#                                                   Ruta   Afinidad     CNN  \
# 0    Mejores_poses/inhibidores/EGFR_P_MAPK1_158_MAP...  -9.656175  active
# 1    Mejores_poses/inhibidores/EGFR_P_MAPK1_159_MAP...  -8.766229  active
# 2    Mejores_poses/inhibidores/EGFR_P_MAPK1_160_MAP... -10.776790  active
# 3    Mejores_poses/inhibidores/EGFR_P_MAPK1_161_MAP...  -9.394532  active
# 4    Mejores_poses/inhibidores/EGFR_P_MAPK1_162_MAP... -10.063492  active
# ..                                                 ...        ...     ...
# 316  Mejores_poses/inhibidores/SRC_P_STAT3_312_STAT...  -5.765594  active
# ...

# %%
df_inhib_triples
# Out:
#                Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 0  SRC_P_EGFR_STAT3_157  -10.081927   -8.411198          ('A'          ('A'
#
#     CNN_1   CNN_2                                             Ruta_1  \
# 0  active  active  Mejores_poses/inhibidores/SRC_P_EGFR_STAT3_157...
#
#                                               Ruta_2 Target_1 Target_2
# 0  Mejores_poses/inhibidores/SRC_P_EGFR_STAT3_157...     EGFR    STAT3

# %% [markdown]
# # Analizar bases conjuntas
# <hr>

# %%
df_bases["Targets"] = df_bases["Target_1"] + "_" + df_bases["Target_2"]

# %%
df_bases["Targets"].value_counts()
# Out:
# Targets
# EGFR_MAPK1    554
# EGFR_SRC       19
# EGFR_STAT3     16
# MAPK1_SRC       1
# Name: count, dtype: int64

# %%
# Obtener aquellos mejores o iguales a EGFR y MAPK1

df_EGFR_MAPK1 = df_bases[df_bases["Targets"] == "EGFR_MAPK1"]
df_EGFR_MAPK1_mejores = df_EGFR_MAPK1[(df_EGFR_MAPK1["Afinidad_1"] <= my_dick["EGFR"]) & (df_EGFR_MAPK1["Afinidad_2"] <= my_dick["MAPK1"])]
df_EGFR_MAPK1_mejores
# Out:
#            Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 4    EGFR_MAPK1_101  -10.027432  -10.522901          ('A'          ('A'
# 18   EGFR_MAPK1_114   -9.835052  -10.348002          ('A'          ('A'
# 21   EGFR_MAPK1_117  -10.195214  -10.207559          ('A'          ('A'
# 40   EGFR_MAPK1_134  -10.132882  -10.266725          ('A'          ('A'
# 42   EGFR_MAPK1_136   -9.852680  -10.731030          ('A'          ('A'
# 53   EGFR_MAPK1_146  -10.840947  -10.321940          ('A'          ('A'
# 76   EGFR_MAPK1_167  -10.234542  -10.266648          ('A'          ('A'
# 91   EGFR_MAPK1_180  -10.409719  -11.130693          ('A'          ('A'
# 134  EGFR_MAPK1_219  -10.571246  -10.296425          ('A'          ('A'
# 138  EGFR_MAPK1_223  -10.493924  -11.051113          ('A'          ('A'
# 160  EGFR_MAPK1_243  -10.518848  -10.193906          ('A'          ('A'
# 164  EGFR_MAPK1_247   -9.948353  -10.290463          ('A'          ('A'
# ...

# %%
# Obtener aquellos mejores o iguales a EGFR y SRC

df_EGFR_SRC = df_bases[df_bases["Targets"] == "EGFR_SRC"]
df_EGFR_SRC_mejores = df_EGFR_SRC[(df_EGFR_SRC["Afinidad_1"] <= my_dick["EGFR"]) & (df_EGFR_SRC["Afinidad_2"] <= my_dick["SRC"])]
df_EGFR_SRC_mejores
# Out:
#          Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2   CNN_1  \
# 554  EGFR_SRC_555  -12.281394  -10.378899          ('A'          ('A'  active
# 555  EGFR_SRC_556  -11.482841  -10.202649          ('A'          ('A'  active
# 556  EGFR_SRC_557  -11.586112  -10.348011          ('A'          ('A'  active
# 557  EGFR_SRC_558  -11.493243  -10.737465          ('A'          ('A'  active
# 558  EGFR_SRC_559  -11.936803  -10.547444          ('A'          ('A'  active
# 559  EGFR_SRC_560  -11.663652  -10.335987          ('A'          ('A'  active
# 560  EGFR_SRC_561  -10.774304  -10.007732          ('A'          ('A'  active
# 561  EGFR_SRC_562  -11.135662  -10.494559          ('A'          ('A'  active
# 562  EGFR_SRC_563  -11.982425  -10.299003          ('A'          ('A'  active
# 563  EGFR_SRC_564  -11.626127   -9.953917          ('A'          ('A'  active
# 564  EGFR_SRC_565  -11.939290  -10.491311          ('A'          ('A'  active
# ...

# %%
# Obtener aquellos mejores o iguales a EGFR y STAT3
df_EGFR_STAT3 = df_bases[df_bases["Targets"] == "EGFR_STAT3"]

df_EGFR_STAT3_mejores = df_EGFR_STAT3[
    (df_EGFR_STAT3["Afinidad_1"] <= my_dick["EGFR"]) &
    (df_EGFR_STAT3["Afinidad_2"] <= my_dick["STAT3"])
]
df_EGFR_STAT3_mejores
# Out:
# Empty DataFrame
# Columns: [Molecula, Afinidad_1, Afinidad_2, CNN afinity_1, CNN afinity_2, CNN_1, CNN_2, Ruta_1, Ruta_2, Target_1, Target_2, Targets]
# Index: []

# %%
# Obtener aquellos mejores o iguales a MAPK1 y SRC
df_MAPK1_SRC = df_bases[df_bases["Targets"] == "MAPK1_SRC"]

df_MAPK1_SRC_mejores = df_MAPK1_SRC[
    (df_MAPK1_SRC["Afinidad_1"] <= my_dick["MAPK1"]) &
    (df_MAPK1_SRC["Afinidad_2"] <= my_dick["SRC"])
]
df_MAPK1_SRC_mejores
# Out:
# Empty DataFrame
# Columns: [Molecula, Afinidad_1, Afinidad_2, CNN afinity_1, CNN afinity_2, CNN_1, CNN_2, Ruta_1, Ruta_2, Target_1, Target_2, Targets]
# Index: []

# %% [markdown]
# # Analizar inhibidores
# <hr>

# %%
df_inhib_dual
# Out:
#              Molecula Target  \
# 0    EGFR_P_MAPK1_158  MAPK1
# 1    EGFR_P_MAPK1_159  MAPK1
# 2    EGFR_P_MAPK1_160  MAPK1
# 3    EGFR_P_MAPK1_161  MAPK1
# 4    EGFR_P_MAPK1_162  MAPK1
# ..                ...    ...
# 316   SRC_P_STAT3_312  STAT3
# 317   SRC_P_STAT3_313  STAT3
# 318   SRC_P_STAT3_314  STAT3
# 319   SRC_P_STAT3_315  STAT3
# 320   SRC_P_STAT3_316  STAT3
#
#                                                   Ruta   Afinidad     CNN  \
# 0    Mejores_poses/inhibidores/EGFR_P_MAPK1_158_MAP...  -9.656175  active
# 1    Mejores_poses/inhibidores/EGFR_P_MAPK1_159_MAP...  -8.766229  active
# 2    Mejores_poses/inhibidores/EGFR_P_MAPK1_160_MAP... -10.776790  active
# 3    Mejores_poses/inhibidores/EGFR_P_MAPK1_161_MAP...  -9.394532  active
# 4    Mejores_poses/inhibidores/EGFR_P_MAPK1_162_MAP... -10.063492  active
# ..                                                 ...        ...     ...
# 316  Mejores_poses/inhibidores/SRC_P_STAT3_312_STAT...  -5.765594  active
# ...

# %%
df_inhib_dual["Target"].value_counts()
# Out:
# Target
# EGFR     157
# STAT3     85
# MAPK1     48
# SRC       29
# Name: count, dtype: int64

# %%
df_inhib_dual
# Out:
#              Molecula Target  \
# 0    EGFR_P_MAPK1_158  MAPK1
# 1    EGFR_P_MAPK1_159  MAPK1
# 2    EGFR_P_MAPK1_160  MAPK1
# 3    EGFR_P_MAPK1_161  MAPK1
# 4    EGFR_P_MAPK1_162  MAPK1
# ..                ...    ...
# 316   SRC_P_STAT3_312  STAT3
# 317   SRC_P_STAT3_313  STAT3
# 318   SRC_P_STAT3_314  STAT3
# 319   SRC_P_STAT3_315  STAT3
# 320   SRC_P_STAT3_316  STAT3
#
#                                                   Ruta   Afinidad     CNN  \
# 0    Mejores_poses/inhibidores/EGFR_P_MAPK1_158_MAP...  -9.656175  active
# 1    Mejores_poses/inhibidores/EGFR_P_MAPK1_159_MAP...  -8.766229  active
# 2    Mejores_poses/inhibidores/EGFR_P_MAPK1_160_MAP... -10.776790  active
# 3    Mejores_poses/inhibidores/EGFR_P_MAPK1_161_MAP...  -9.394532  active
# 4    Mejores_poses/inhibidores/EGFR_P_MAPK1_162_MAP... -10.063492  active
# ..                                                 ...        ...     ...
# 316  Mejores_poses/inhibidores/SRC_P_STAT3_312_STAT...  -5.765594  active
# ...

# %%
# Determinar aquellos mejores para EGFR
EGFR_dual =df_inhib_dual[(df_inhib_dual["Target"] == "EGFR") & (df_inhib_dual["Afinidad"] <= my_dick["EGFR"])]

# %%
EGFR_dual
# Out:
#             Molecula Target  \
# 120   MAPK1_P_EGFR_0   EGFR
# 125  MAPK1_P_EGFR_14   EGFR
# 129  MAPK1_P_EGFR_18   EGFR
# 132  MAPK1_P_EGFR_20   EGFR
# 136  MAPK1_P_EGFR_24   EGFR
# ..               ...    ...
# 277    SRC_P_EGFR_92   EGFR
# 278    SRC_P_EGFR_93   EGFR
# 280    SRC_P_EGFR_95   EGFR
# 281    SRC_P_EGFR_96   EGFR
# 282    SRC_P_EGFR_97   EGFR
#
#                                                   Ruta   Afinidad     CNN  \
# 120  Mejores_poses/inhibidores/MAPK1_P_EGFR_0_EGFR....  -9.873798  active
# 125  Mejores_poses/inhibidores/MAPK1_P_EGFR_14_EGFR...  -9.668670  active
# 129  Mejores_poses/inhibidores/MAPK1_P_EGFR_18_EGFR...  -9.393104  active
# 132  Mejores_poses/inhibidores/MAPK1_P_EGFR_20_EGFR...  -9.341337  active
# 136  Mejores_poses/inhibidores/MAPK1_P_EGFR_24_EGFR...  -9.505371  active
# ..                                                 ...        ...     ...
# 277  Mejores_poses/inhibidores/SRC_P_EGFR_92_EGFR.p... -10.547513  active
# ...

# %%
# Determinar aquellos mejores para MAPK1
MAPK1_dual =df_inhib_dual[(df_inhib_dual["Target"] == "MAPK1") & (df_inhib_dual["Afinidad"] <= my_dick["MAPK1"])]

# %%
MAPK1_dual
# Out:
#                  Molecula Target  \
# 2        EGFR_P_MAPK1_160  MAPK1
# 13       EGFR_P_MAPK1_171  MAPK1
# 14       EGFR_P_MAPK1_172  MAPK1
# 15       EGFR_P_MAPK1_173  MAPK1
# 212  SRC_EGFR_P_MAPK1_204  MAPK1
# 288       SRC_P_MAPK1_176  MAPK1
# 315       SRC_P_MAPK1_203  MAPK1
#
#                                                   Ruta   Afinidad     CNN  \
# 2    Mejores_poses/inhibidores/EGFR_P_MAPK1_160_MAP... -10.776790  active
# 13   Mejores_poses/inhibidores/EGFR_P_MAPK1_171_MAP... -10.785744  active
# 14   Mejores_poses/inhibidores/EGFR_P_MAPK1_172_MAP... -10.554493  active
# 15   Mejores_poses/inhibidores/EGFR_P_MAPK1_173_MAP... -10.307150  active
# 212  Mejores_poses/inhibidores/SRC_EGFR_P_MAPK1_204... -10.962621  active
# 288  Mejores_poses/inhibidores/SRC_P_MAPK1_176_MAPK... -10.305790  active
# 315  Mejores_poses/inhibidores/SRC_P_MAPK1_203_MAPK... -10.635925  active
#
#     CNN afinity
# 2          ('A'
# 13         ('A'
# 14         ('A'
# 15         ('A'
# ...

# %%
# Determinar aquellos mejores para SRC
SRC_dual = df_inhib_dual[(df_inhib_dual["Target"] == "SRC") & (df_inhib_dual["Afinidad"] <= my_dick["SRC"])]

# %%
SRC_dual
# Out:
#           Molecula Target                                               Ruta  \
# 17  EGFR_P_SRC_206    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_206_SRC.p...
# 18  EGFR_P_SRC_207    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_207_SRC.p...
# 19  EGFR_P_SRC_208    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_208_SRC.p...
# 20  EGFR_P_SRC_209    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_209_SRC.p...
# 21  EGFR_P_SRC_210    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_210_SRC.p...
# 22  EGFR_P_SRC_211    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_211_SRC.p...
# 23  EGFR_P_SRC_212    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_212_SRC.p...
# 24  EGFR_P_SRC_213    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_213_SRC.p...
# 25  EGFR_P_SRC_214    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_214_SRC.p...
# 26  EGFR_P_SRC_215    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_215_SRC.p...
# 27  EGFR_P_SRC_216    SRC  Mejores_poses/inhibidores/EGFR_P_SRC_216_SRC.p...
# ...

# %%
# Determinar aquellos mejores para STAT3
df_inhib_dual[(df_inhib_dual["Target"] == "STAT3") & (df_inhib_dual["Afinidad"] <= my_dick["STAT3"])]
# Out:
#             Molecula Target  \
# 92  EGFR_P_STAT3_281  STAT3
#
#                                                  Ruta  Afinidad     CNN  \
# 92  Mejores_poses/inhibidores/EGFR_P_STAT3_281_STA... -9.641184  active
#
#    CNN afinity
# 92        ('A'

# %%
my_dick
# Out:
# {'EGFR': -9.29, 'MAPK1': -10.15, 'SRC': -7.8, 'STAT3': -9.41}

# %%
# Determinar aquellos triples

df_inhib_triples # No aplica
# Out:
#                Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 0  SRC_P_EGFR_STAT3_157  -10.081927   -8.411198          ('A'          ('A'
#
#     CNN_1   CNN_2                                             Ruta_1  \
# 0  active  active  Mejores_poses/inhibidores/SRC_P_EGFR_STAT3_157...
#
#                                               Ruta_2 Target_1 Target_2
# 0  Mejores_poses/inhibidores/SRC_P_EGFR_STAT3_157...     EGFR    STAT3

# %%
# 1 = 1, 1
# 2 = 0, 0
# 3 = 1, 0
# 4 = 1, 0
# 5 = 0, 0

# %%
df_inhib_triples
# Out:
#                Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 0  SRC_P_EGFR_STAT3_157  -10.081927   -8.411198          ('A'          ('A'
#
#     CNN_1   CNN_2                                             Ruta_1  \
# 0  active  active  Mejores_poses/inhibidores/SRC_P_EGFR_STAT3_157...
#
#                                               Ruta_2 Target_1 Target_2
# 0  Mejores_poses/inhibidores/SRC_P_EGFR_STAT3_157...     EGFR    STAT3

# %% [markdown]
# # Guardar datos
# <hr>

# %%
# df_EGFR_SRC_mejores > Mejores de las bases para EGFR y SRC
# df_EGFR_MAPK1_mejores > Mejores de las bases para EGFR y MAPK1
# df_EGFR_SRC_mejores > Mejores de las bases para EGFR y SRC
# EGFR_dual > Mejores EGFR de inhibidores
# MAPK1_dual > Mejores MAPK1 de inhibidores
# SRC_dual > Mejores SRC de inhibidores
# STAT3_dual > Mejores STAT3 de inhibidores (ninguno)
# df_inhib_triples > Mejores triples de inhibidores

# %%
df_EGFR_MAPK1_mejores.shape[0] + df_EGFR_SRC_mejores.shape[0]
# Out:
# 66

# %%
EGFR_dual.shape[0] + MAPK1_dual.shape[0] + SRC_dual.shape[0] + df_inhib_triples.shape[0]
# Out:
# 106

# %%
df_bases = pd.concat([df_EGFR_MAPK1_mejores, df_EGFR_SRC_mejores ], axis=0)

# %%
df_duales = pd.concat([EGFR_dual, MAPK1_dual, SRC_dual], axis=0)

# %%
df_bases["Targets"].value_counts()
# Out:
# Targets
# EGFR_MAPK1    52
# EGFR_SRC      14
# Name: count, dtype: int64

# %%
df_duales["Target"].value_counts()
# Out:
# Target
# EGFR     71
# SRC      27
# MAPK1     7
# Name: count, dtype: int64

# %% [markdown]
# # Guardar datos
# <hr>

# %%
df_bases
# Out:
#            Molecula  Afinidad_1  Afinidad_2 CNN afinity_1 CNN afinity_2  \
# 4    EGFR_MAPK1_101  -10.027432  -10.522901          ('A'          ('A'
# 18   EGFR_MAPK1_114   -9.835052  -10.348002          ('A'          ('A'
# 21   EGFR_MAPK1_117  -10.195214  -10.207559          ('A'          ('A'
# 40   EGFR_MAPK1_134  -10.132882  -10.266725          ('A'          ('A'
# 42   EGFR_MAPK1_136   -9.852680  -10.731030          ('A'          ('A'
# ..              ...         ...         ...           ...           ...
# 563    EGFR_SRC_564  -11.626127   -9.953917          ('A'          ('A'
# 564    EGFR_SRC_565  -11.939290  -10.491311          ('A'          ('A'
# 565    EGFR_SRC_566  -11.901248  -10.111121          ('A'          ('A'
# 566    EGFR_SRC_567  -11.347662  -10.426674          ('A'          ('A'
# 568    EGFR_SRC_569  -10.000343   -9.550843          ('A'          ('A'
#
#       CNN_1   CNN_2                                             Ruta_1  \
# ...

# %%
df_duales
# Out:
#             Molecula Target  \
# 120   MAPK1_P_EGFR_0   EGFR
# 125  MAPK1_P_EGFR_14   EGFR
# 129  MAPK1_P_EGFR_18   EGFR
# 132  MAPK1_P_EGFR_20   EGFR
# 136  MAPK1_P_EGFR_24   EGFR
# ..               ...    ...
# 40    EGFR_P_SRC_229    SRC
# 41    EGFR_P_SRC_230    SRC
# 42    EGFR_P_SRC_231    SRC
# 44    EGFR_P_SRC_233    SRC
# 45    EGFR_P_SRC_234    SRC
#
#                                                   Ruta   Afinidad     CNN  \
# 120  Mejores_poses/inhibidores/MAPK1_P_EGFR_0_EGFR....  -9.873798  active
# 125  Mejores_poses/inhibidores/MAPK1_P_EGFR_14_EGFR...  -9.668670  active
# 129  Mejores_poses/inhibidores/MAPK1_P_EGFR_18_EGFR...  -9.393104  active
# 132  Mejores_poses/inhibidores/MAPK1_P_EGFR_20_EGFR...  -9.341337  active
# 136  Mejores_poses/inhibidores/MAPK1_P_EGFR_24_EGFR...  -9.505371  active
# ..                                                 ...        ...     ...
# 40   Mejores_poses/inhibidores/EGFR_P_SRC_229_SRC.p... -10.237829  active
# ...

# %%
df_bases.to_csv("df_mejores/Bases/bases.csv", index=False)

# %%
df_duales.to_csv("df_mejores/Inhibidores/duales.csv", index=False)
